# %%
import matplotlib.pyplot as plt

# %%
#disorder vs count
srbd=28
parasomnia=1
cdof=7
crswd=1
insomnia=3
other=2
missing=7
counts=[srbd,parasomnia,cdof,crswd,insomnia,other,missing]

data = {'Sleep-related \n Breathing \n Disorders':28, 'Parasomnia':1, 'Central Disorders of \n Hypersomnolence':7,
        'Circadian rhythm \n sleep-wake disorders':1,'Insonmnia':3,'Other Sleep Disorders':2,
        'Missing':7}
disorders = list(data.keys())
values = list(data.values())

fig = plt.figure()

fig.set_figwidth(14)

plt.bar(disorders, values, color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 7 artists>

# %%
#accuracy in different disorders
